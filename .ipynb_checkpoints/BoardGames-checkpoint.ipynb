# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from pandas import DataFrame
import time
import datetime


df = pd.read_csv('C:\\Users\\maria\\Desktop\\MyJupyter\\board-games-dataset\\bgg_db_2018_01.csv',encoding = "ISO-8859-1")

# %%
df = df.drop(['game_id','bgg_url','image_url','avg_rating','geek_rating','min_time','max_time'],axis=1)
df.head()
# Out:
#    rank                                          names  min_players  \
# 0     1                                     Gloomhaven            1
# 1     2                      Pandemic Legacy: Season 1            2
# 2     3  Through the Ages: A New Story of Civilization            2
# 3     4                              Twilight Struggle            2
# 4     5                              Terraforming Mars            1
#
#    max_players  avg_time  year  num_votes  age  \
# 0            4       150  2017       9841   12
# 1            4        60  2015      23489   13
# 2            4       240  2015      10679   14
# 3            2       180  2005      29923   13
# 4            5       120  2016      20468   12
#
#                                             mechanic  owned  \
# 0  Action / Movement Programming, Co-operative Pl...  18217
# 1  Action Point Allowance System, Co-operative Pl...  38105
# 2  Action Point Allowance System, Auction/Bidding...  14147
# ...

# %%
df.describe()
# Out:
#               rank  min_players  max_players      avg_time         year  \
# count  4999.000000  4999.000000  4999.000000   4999.000000  4999.000000
# mean   2500.000000     2.027205     5.377475    115.241648  1997.739348
# std    1443.231328     0.681943    16.075743    509.802841   140.357756
# min       1.000000     0.000000     0.000000      0.000000 -3000.000000
# 25%    1250.500000     2.000000     4.000000     30.000000  2003.000000
# 50%    2500.000000     2.000000     4.000000     60.000000  2010.000000
# 75%    3749.500000     2.000000     6.000000    120.000000  2014.000000
# max    4999.000000     8.000000   999.000000  22500.000000  2018.000000
#
#           num_votes          age          owned       weight
# count   4999.000000  4999.000000    4999.000000  4999.000000
# mean    1899.070414    10.357872    2881.595519     2.348847
# std     4516.589213     3.281167    6133.483042     0.801396
# min       55.000000     0.000000      46.000000     0.000000
# ...

# %%
df.corr().plot()

# %%
df['rank'].plot()

# %%
df['min_players'].plot()

# %%
df['max_players'].plot()

# %%
df['avg_time'].plot()

# %%
df['year'].plot()

# %%
df['num_votes'].plot()

# %%
df['age'].plot()

# %%
df['owned'].plot()

# %%
df['weight'].plot()
