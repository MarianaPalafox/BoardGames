# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from pandas import DataFrame
import time
import datetime


df = pd.read_csv('C:\\Users\\maria\\Desktop\\MyJupyter\\BoardGames\\bgg_db_2018_01.csv',encoding = "ISO-8859-1")

# %%
df = df.drop(['game_id','bgg_url','image_url','avg_rating','geek_rating','min_time','max_time', 'year'],axis=1)
# Se quito el año ya que es irrelevante
# Eliminar filas en que el numero de jugadores es 0
df = df.drop(df[df.min_players == 0].index)
df = df.drop(df[df.age <= 0].index)
df = df.drop(df[df.weight < 0].index)
df = df.drop(df[df.avg_time <= 0].index)0
df.head()
# Out:
#    rank                                          names  min_players  \
# 0     1                                     Gloomhaven            1
# 1     2                      Pandemic Legacy: Season 1            2
# 2     3  Through the Ages: A New Story of Civilization            2
# 3     4                              Twilight Struggle            2
# 4     5                              Terraforming Mars            1
#
#    max_players  avg_time  num_votes  age  \
# 0            4       150       9841   12
# 1            4        60      23489   13
# 2            4       240      10679   14
# 3            2       180      29923   13
# 4            5       120      20468   12
#
#                                             mechanic  owned  \
# 0  Action / Movement Programming, Co-operative Pl...  18217
# 1  Action Point Allowance System, Co-operative Pl...  38105
# 2  Action Point Allowance System, Auction/Bidding...  14147
# ...

# %%
df.describe()
# Out:
#               rank  min_players  max_players      avg_time     num_votes  \
# count  4760.000000  4760.000000  4760.000000   4760.000000   4760.000000
# mean   2467.491597     2.037815     5.459244    107.893487   1974.465756
# std    1445.806033     0.675447    16.399292    451.675759   4614.635012
# min       1.000000     1.000000     0.000000      0.000000     55.000000
# 25%    1207.750000     2.000000     4.000000     30.000000    281.000000
# 50%    2452.500000     2.000000     4.000000     60.000000    613.500000
# 75%    3718.250000     2.000000     6.000000     90.000000   1613.250000
# max    4999.000000     8.000000   999.000000  22500.000000  74261.000000
#
#                age          owned       weight
# count  4760.000000    4760.000000  4760.000000
# mean     10.869748    2982.121429     2.331954
# std       2.395768    6266.187156     0.796416
# min       2.000000      46.000000     0.000000
# 25%      10.000000     607.750000     1.727300
# ...

# %%
df.corr().plot()

# %%
df['rank'].plot()

# %%
df['min_players'].plot()

# %%
df['max_players'].plot()

# %%
df['avg_time'].plot()

# %%
df['num_votes'].plot()

# %%
df['age'].plot()

# %%
df['owned'].plot()

# %%
df['weight'].plot()

# %%
plt.scatter(df.weight, df.avg_time)
